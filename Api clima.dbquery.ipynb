-- %%
SELECT 
    cidade,
    temperatura,
    sensacao,
    umidade,
    clima,
    latitude,
    longitude,
    data_ingestao
FROM aprender_data.tabela_clima_capitais
-- Esse comando mágico abaixo pega apenas a ÚLTIMA leitura de cada cidade
-- Ele evita que o mapa mostre dados velhos duplicados
QUALIFY row_number() OVER (PARTITION BY cidade ORDER BY data_ingestao DESC) = 1
-- Out:
-- Databricks visualization. Run in Databricks to view.
